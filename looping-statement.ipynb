# %% [markdown]
# # **looping statements are used to repeat a block of code multiple times**

# %% [markdown]
# # For loop
# ## For loop is used to iterate over a sequence (like a list, string, tuple, or range) and execute a block of code multiple times.

# %% [markdown]
# for variable in sequence:
#
#     # code block

# %% [markdown]
# ## 1. Using range()

# %%
for i in range(5):
    print(i)

# %% [markdown]
# ## 2. Loop Through a List

# %%
studentnames = ["suresh ", "mahesh ", "rana"]

for i in studentnames:
    print(i)

# %% [markdown]
# ## 3.3: Loop Through a String

# %%
for letter in "Python":
    print(letter)

# %% [markdown]
# ## 4: Using range(start, stop, step)

# %%
for i in range(1, 10, 1): # implement steping with 1
    print(i)

# %%
for i in range(1, 10, 3): # implemet stp with 3
    print(i)

# %% [markdown]
# # Advance looping using for

# %%
for i in range(1, 6): #start from 1 to 5
    print("*" * i) # prints multiple stars

# %%
for i in range(5, 0, -1): # start from 5 to 1 
    print("*" * i)

# %% [markdown]
# # While loop
# The while loop in Python is used to repeat a block of code as long as a condition is True.

# %% [markdown]
# while condition:
#
#     # code block

# %%
i = 1
while i < 5: #condition
    print(i)
    i += 1

# %% [markdown]
# ## Infinite loop

# %%
while True:
    print("Hello")

# %%
i = 5
while i >= 1:
    print(i)
    i -= 1

# %% [markdown]
# #  Loop Control Statements
#
# ## 1. break
#
# Stops the loop completely.

# %%
for i in range(5):
    if i == 3: # break execution here
        break
    print(i)

# %%
i = 1
while i < 5: #condition
    print(i)
    if i == 3:
        break
    i += 1

# %% [markdown]
# ## 2. continue
#
# Skips current iteration and moves to next.

# %%
for i in range(5):
    if i == 2:
        continue #skip current iteration
    print(i)

# %% [markdown]
# ## 3. pass
#
# Does nothing (placeholder).

# %%
for i in range(5):
    pass

# %%
# with class
class helllo:
    print("started")
    pass

# %%
# with functions
def my_function():
    pass
